# %%
# Here I will be looking at the Recruit Restaurant Visitor Forecasting dataset from Kaggle

# %%
# From data source:

# -Hot Pepper Gourmet (hpg): similar to Yelp, here users can search restaurants and also make a reservation online

# -AirREGI / Restaurant Board (air): similar to Square, a reservation control and cash register system

# Files:
    
# air_reserve.csv - This file contains reservations made in the air system. Note that the reserve_datetime indicates the time when the reservation was created, whereas the visit_datetime is the time in the future where the visit will occur.

# hpg_reserve.csv - This file contains reservations made in the hpg system.

# air_store_info.csv - This file contains information about select air restaurants. Column names and contents are self-explanatory.

# hpg_store_info.csv - This file contains information about select hpg restaurants. Column names and contents are self-explanatory.

# store_id_relation.csv - This file allows you to join select restaurants that have both the air and hpg system.

# air_visit_data.csv - This file contains historical visit data for the air restaurants.

# date_info.csv - This file gives basic information about the calendar dates in the dataset.

# %%
import os,sys
import json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import descartes
import geopandas as gpd

# %%
air_reserve = pd.read_csv('../Datasets/restaurants_japan/air_reserve.csv',parse_dates=['visit_datetime','reserve_datetime'])
air_store = pd.read_csv('../Datasets/restaurants_japan/air_store_info.csv')
hpg_reserve = pd.read_csv('../Datasets/restaurants_japan/hpg_reserve.csv',parse_dates=['visit_datetime','reserve_datetime'])
hpg_store = pd.read_csv('../Datasets/restaurants_japan/hpg_store_info.csv')
air_visit = pd.read_csv('../Datasets/restaurants_japan/air_visit_data.csv')
store_id_relation = pd.read_csv('../Datasets/restaurants_japan/store_id_relation.csv')
date_info = pd.read_csv('../Datasets/restaurants_japan/date_info.csv')

# %%
# We can combine the air and hpg csvs into singular dataframes

# %%
df_hpg = pd.merge(hpg_reserve, hpg_store, on='hpg_store_id')
df_air = pd.merge(air_reserve, air_store, on='air_store_id')

# %%
df_hpg_relation = pd.merge(df_hpg,store_id_relation, how='left', on = 'hpg_store_id')
df_air_relation = pd.merge(df_air,store_id_relation, how='left', on = 'air_store_id')

# %%
# Merge all

df_full = pd.merge(df_hpg_relation,df_air_relation, how='outer')

# %%
df_full
# Out:
#                 hpg_store_id      visit_datetime    reserve_datetime  \
# 0       hpg_dac72789163a3f47 2016-01-01 13:00:00 2016-01-01 06:00:00
# 1       hpg_dac72789163a3f47 2016-01-02 12:00:00 2016-01-01 20:00:00
# 2       hpg_dac72789163a3f47 2016-01-03 19:00:00 2016-01-02 15:00:00
# 3       hpg_dac72789163a3f47 2016-01-06 12:00:00 2016-01-06 08:00:00
# 4       hpg_dac72789163a3f47 2016-01-10 17:00:00 2016-01-04 22:00:00
# ...                      ...                 ...                 ...
# 963681                   NaN 2017-05-16 19:00:00 2017-04-20 19:00:00
# 963682                   NaN 2017-05-21 18:00:00 2017-04-20 19:00:00
# 963683                   NaN 2017-05-21 19:00:00 2017-04-20 19:00:00
# 963684  hpg_e41e0f2c318dd8e4 2017-04-20 23:00:00 2017-04-20 10:00:00
# 963685                   NaN 2017-05-23 19:00:00 2017-04-14 16:00:00
#
#         reserve_visitors hpg_genre_name            hpg_area_name   latitude  \
# 0                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# 1                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 2                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 3                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 4                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# ...                  ...            ...                      ...        ...
# 963681                 3            NaN                      NaN  35.658068
# 963682                 4            NaN                      NaN  35.658068
# 963683                 2            NaN                      NaN  35.658068
# 963684                 2            NaN                      NaN  34.705362
# 963685                11            NaN                      NaN  38.269076
#
#          longitude          air_store_id air_genre_name  \
# 0       135.191698                   NaN            NaN
# 1       135.191698                   NaN            NaN
# 2       135.191698                   NaN            NaN
# 3       135.191698                   NaN            NaN
# 4       135.191698                   NaN            NaN
# ...            ...                   ...            ...
# 963681  139.751599  air_b3a824511477a4ed  Japanese food
# 963682  139.751599  air_b3a824511477a4ed  Japanese food
# 963683  139.751599  air_b3a824511477a4ed  Japanese food
# 963684  135.510025  air_cf2229e64408d9fe     Dining bar
# 963685  140.870403  air_e700e390226d9985        Izakaya
#
#                          air_area_name
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 963681    Tōkyō-to Minato-ku Shibakōen
# 963682    Tōkyō-to Minato-ku Shibakōen
# 963683    Tōkyō-to Minato-ku Shibakōen
# 963684     Ōsaka-fu Ōsaka-shi Ōgimachi
# 963685  Miyagi-ken Sendai-shi Kamisugi
#
# [963686 rows x 11 columns]

# %%
# Change dates to ensure datetime objects
df_air['visit_datetime'] = pd.to_datetime(df_air['visit_datetime'])
df_air['reserve_datetime'] = pd.to_datetime(df_air['reserve_datetime'])
df_hpg['visit_datetime'] = pd.to_datetime(df_hpg['visit_datetime'])
df_hpg['reserve_datetime'] = pd.to_datetime(df_hpg['reserve_datetime'])
df_full['visit_datetime'] = pd.to_datetime(df_full['visit_datetime'])
df_full['reserve_datetime'] = pd.to_datetime(df_full['reserve_datetime'])

# %%
# Cumulating the reserve times and visit, adding up all the visitors
cum_df_reserve = df_full.groupby(['reserve_datetime']).sum().sort_values(by=['reserve_datetime'],ascending=True)
cum_df_visit = df_full.groupby(['visit_datetime']).sum().sort_values(by=['visit_datetime'],ascending=True)

# %%
cum_df_reserve.head()
# Out:
#                      reserve_visitors    latitude    longitude
# reserve_datetime
# 2016-01-01 00:00:00                90  704.917747  2642.569365
# 2016-01-01 01:00:00                57  415.084550  1509.784428
# 2016-01-01 02:00:00                15  195.043211   701.673945
# 2016-01-01 03:00:00                27  174.709774   686.295219
# 2016-01-01 04:00:00                40  211.888717   818.645405

# %%
cum_df_visit.head()
# Out:
#                      reserve_visitors     latitude    longitude
# visit_datetime
# 2016-01-01 13:00:00                 3    34.692109   135.191698
# 2016-01-01 17:00:00                35   471.788971  1790.502448
# 2016-01-01 18:00:00                84   876.081696  3401.770555
# 2016-01-01 19:00:00               106  1239.450177  4759.756826
# 2016-01-01 20:00:00                26   321.175790  1224.093007

# %%
# Doing some clustering


# There are 8 regions in Japan -> 8 clusters: https://en.wikipedia.org/wiki/List_of_regions_of_Japan

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12).fit(df_full[['longitude','latitude']])
df_full['cluster'] = kmeans.predict(df_full[['longitude','latitude']])
cluster_centers = kmeans.cluster_centers_

# %%
# This is the location of the centers of clusters
cluster_centers
# Out:
# array([[133.36215122,  34.48923642],
#        [139.00348924,  37.81631394],
#        [141.32933868,  43.00328219],
#        [139.67880953,  35.67611687],
#        [135.43011786,  34.6887174 ],
#        [130.5142751 ,  33.6349562 ],
#        [137.73607962,  34.71927621],
#        [140.87764688,  38.27511918],
#        [132.4666604 ,  34.3944754 ],
#        [138.45335351,  34.99171211],
#        [134.777444  ,  34.77807319],
#        [142.55745313,  43.69576837]])

# %%
# Looking at cluster histograms
fig,ax = plt.subplots(1,2,figsize=(15,6))
cluster_histogram = df_full.groupby(['cluster'],as_index=False).count()
sns.barplot(x=cluster_histogram['cluster'],y=cluster_histogram['air_store_id'],ax=ax[0], palette= "Set2")
sns.barplot(x=cluster_histogram['cluster'],y=cluster_histogram['hpg_store_id'],ax=ax[1], palette= "Set2")
plt.show()

# %%
cluster_histogram
# Out:
#     cluster  hpg_store_id  visit_datetime  reserve_datetime  reserve_visitors  \
# 0         0          9689           10913             10913             10913
# 1         1         34637           36354             36354             36354
# 2         2         55174           59459             59459             59459
# 3         3        385196          401934            401934            401934
# 4         4        172000          179369            179369            179369
# 5         5         87283           96026             96026             96026
# 6         6         19405           22417             22417             22417
# 7         7         30954           34913             34913             34913
# 8         8         47429           50225             50225             50225
# 9         9         26115           27398             27398             27398
# 10       10         26148           28586             28586             28586
# 11       11         13542           16092             16092             16092
#
#     hpg_genre_name  hpg_area_name  latitude  longitude  air_store_id  \
# 0             9639           9639     10913      10913          1633
# 1            32368          32368     36354      36354          5537
# 2            51135          51135     59459      59459          9588
# 3           372936         372936    401934     401934         32094
# 4           169951         169951    179369     179369         11074
# 5            82756          82756     96026      96026         15362
# 6            17479          17479     22417      22417          5306
# 7            30711          30711     34913      34913          4202
# 8            44175          44175     50225      50225          6649
# 9            24981          24981     27398      27398          2417
# 10           23267          23267     28586      28586          6680
# 11           11910          11910     16092      16092          5364
#
#     air_genre_name  air_area_name
# 0             1274           1274
# 1             3986           3986
# 2             8324           8324
# 3            28998          28998
# 4             9418           9418
# 5            13270          13270
# 6             4938           4938
# 7             4202           4202
# 8             6050           6050
# 9             2417           2417
# 10            5319           5319
# 11            4182           4182

# %%
# Defining cluster count
cluster_count = cluster_histogram['cluster'].count()

# %%
# Define a base map
japan_map = gpd.read_file("../Datasets/restaurants_japan/Igismap/Japan_Boundary.shp")

# %%
# Defining colormaps for clusters
cm = plt.get_cmap('Set2')
colors = [cm(2.*i/cluster_count) for i in range(cluster_count)]
colored = [colors[i] for i in df_full['cluster']]

# %%
fig,ax = plt.subplots(figsize = (20,20))
# Base map
ax1 = japan_map.plot(ax = ax,cmap = 'viridis')
# Plotting cluster centroids 
x = cluster_centers[:,0]
y = cluster_centers[:,1]
ax2 = ax.scatter(x,y ,c= 'y', s = 1000,alpha = 0.9, edgecolors='y', label = 'Cluster Centroids', marker='*')
# Plotting restaurants 
x2 = df_full['longitude']
y2 = df_full['latitude']
ax3 = ax.scatter(x2,y2 ,c= colored, s = 100 , alpha = 0.9,edgecolors='w',label = 'Restaurants')

plt.legend(prop={'size': 20})
plt.title('Map of Japan, with predicted restaurant clusters')


plt.show()

# %%
# Looking at aggregations for day of the week, hours of the day

#Group by days
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday']
week_df_visit = df_full.groupby(df_full['visit_datetime'].dt.day_name()).count().reindex(days)

# %%
df_full
# Out:
#                 hpg_store_id      visit_datetime    reserve_datetime  \
# 0       hpg_dac72789163a3f47 2016-01-01 13:00:00 2016-01-01 06:00:00
# 1       hpg_dac72789163a3f47 2016-01-02 12:00:00 2016-01-01 20:00:00
# 2       hpg_dac72789163a3f47 2016-01-03 19:00:00 2016-01-02 15:00:00
# 3       hpg_dac72789163a3f47 2016-01-06 12:00:00 2016-01-06 08:00:00
# 4       hpg_dac72789163a3f47 2016-01-10 17:00:00 2016-01-04 22:00:00
# ...                      ...                 ...                 ...
# 963681                   NaN 2017-05-16 19:00:00 2017-04-20 19:00:00
# 963682                   NaN 2017-05-21 18:00:00 2017-04-20 19:00:00
# 963683                   NaN 2017-05-21 19:00:00 2017-04-20 19:00:00
# 963684  hpg_e41e0f2c318dd8e4 2017-04-20 23:00:00 2017-04-20 10:00:00
# 963685                   NaN 2017-05-23 19:00:00 2017-04-14 16:00:00
#
#         reserve_visitors hpg_genre_name            hpg_area_name   latitude  \
# 0                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# 1                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 2                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 3                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 4                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# ...                  ...            ...                      ...        ...
# 963681                 3            NaN                      NaN  35.658068
# 963682                 4            NaN                      NaN  35.658068
# 963683                 2            NaN                      NaN  35.658068
# 963684                 2            NaN                      NaN  34.705362
# 963685                11            NaN                      NaN  38.269076
#
#          longitude          air_store_id air_genre_name  \
# 0       135.191698                   NaN            NaN
# 1       135.191698                   NaN            NaN
# 2       135.191698                   NaN            NaN
# 3       135.191698                   NaN            NaN
# 4       135.191698                   NaN            NaN
# ...            ...                   ...            ...
# 963681  139.751599  air_b3a824511477a4ed  Japanese food
# 963682  139.751599  air_b3a824511477a4ed  Japanese food
# 963683  139.751599  air_b3a824511477a4ed  Japanese food
# 963684  135.510025  air_cf2229e64408d9fe     Dining bar
# 963685  140.870403  air_e700e390226d9985        Izakaya
#
#                          air_area_name  cluster
# 0                                  NaN        4
# 1                                  NaN        4
# 2                                  NaN        4
# 3                                  NaN        4
# 4                                  NaN        4
# ...                                ...      ...
# 963681    Tōkyō-to Minato-ku Shibakōen        3
# 963682    Tōkyō-to Minato-ku Shibakōen        3
# 963683    Tōkyō-to Minato-ku Shibakōen        3
# 963684     Ōsaka-fu Ōsaka-shi Ōgimachi        4
# 963685  Miyagi-ken Sendai-shi Kamisugi        7
#
# [963686 rows x 12 columns]

# %%
# Looking at times
time_df_visit = df_full
time_df_visit.index = time_df_visit['visit_datetime']

time_df_visit = time_df_visit.drop(['latitude','longitude'], axis = 1)

# %%
time_df_visit = time_df_visit.groupby(time_df_visit.index.hour).count()

# %%
time_df_visit.head()
# Out:
#                 hpg_store_id  visit_datetime  reserve_datetime  \
# visit_datetime
# 0                       1082            1308              1308
# 1                        726             923               923
# 2                        278             379               379
# 3                        151             198               198
# 4                         95             110               110
#
#                 reserve_visitors  hpg_genre_name  hpg_area_name  air_store_id  \
# visit_datetime
# 0                           1308             878            878           450
# 1                            923             593            593           338
# 2                            379             190            190           191
# 3                            198              80             80           119
# 4                            110              55             55            56
#
#                 air_genre_name  air_area_name  cluster
# visit_datetime
# 0                          430            430     1308
# 1                          330            330      923
# 2                          189            189      379
# 3                          118            118      198
# 4                           55             55      110

# %%
# Looking at time of day and day of week hisograms for actual visitors
fig,ax = plt.subplots(1,2,figsize=(15,6))
sns.barplot(x=week_df_visit.index,y=week_df_visit['reserve_visitors'],ax=ax[0], palette= "Set2")
sns.barplot(x=time_df_visit.index,y=time_df_visit['reserve_visitors'],ax=ax[1], palette= "Set2")
plt.show()

# %%
# As expected, Friday and Sturday dinner times are massively more statistically relevant than other times and days

# %%
# Distribution of
fig,ax = plt.subplots(1,2,figsize=(16,6))
air_histogram = df_air.groupby(['air_store_id']).count()
sns.histplot(air_histogram['visit_datetime'], kde = True, ax=ax[0])
hpg_histogram = df_hpg.groupby(['hpg_store_id']).count()
sns.histplot(hpg_histogram['visit_datetime'], kde = True, ax=ax[1])
plt.show()

# %%
# Number of visits in any given day, month and week

fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize = (24,12))
ax1.plot(cum_df_visit['reserve_visitors'])
ax1.set_title("Visits during full period")
plt.ylabel("Number of visit")
ax2.plot(cum_df_visit['reserve_visitors']['2016-12-01 00:00:00':'2017-01-01 0:00:00'])
ax2.set_title("Visits in a month")
plt.ylabel("Number of visits")
ax3.plot(cum_df_visit['reserve_visitors']['2016-12-01 00:00:00':'2016-12-07 0:00:00'])
ax3.set_title("Visits in a week")
plt.ylabel("Number of visits")
ax4.plot(cum_df_visit['reserve_visitors']['2016-11-01 00:00:00':'2016-11-02 00:00:00'])
ax4.set_title("Visits in a day")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.show()

# %%
# Looking at discrepancy between number of reservations and actual visits for same time ranges

# %%
fig,ax1 = plt.subplots(figsize = (18,12))
ax1.plot(cum_df_visit['reserve_visitors'], label = 'Visit')
ax1.plot(cum_df_reserve['reserve_visitors'], label = 'Reservations')
ax1.set_title("Visits vs Reservations during full period")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
fig,ax1 = plt.subplots(figsize = (18,12))
ax1.plot(cum_df_visit['reserve_visitors']['2016-12-01 00:00:00':'2017-01-01 0:00:00'], label = 'Visit')
ax1.plot(cum_df_reserve['reserve_visitors']['2016-12-01 00:00:00':'2017-01-01 0:00:00'], label = 'Reservations')
ax1.set_title("Visits vs Reservations during a month")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
fig,ax1 = plt.subplots(figsize = (18,12))
ax1.plot(cum_df_visit['reserve_visitors']['2016-12-01 00:00:00':'2016-12-07 0:00:00'], label = 'Visit')
ax1.plot(cum_df_reserve['reserve_visitors']['2016-12-01 00:00:00':'2016-12-07 0:00:00'], label = 'Reservations')
ax1.set_title("Visits vs Reservations during a month")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
fig,ax1 = plt.subplots(figsize = (18,12))
ax1.plot(cum_df_visit['reserve_visitors']['2016-11-01 00:00:00':'2016-11-02 00:00:00'], label = 'Visit')
ax1.plot(cum_df_reserve['reserve_visitors']['2016-11-01 00:00:00':'2016-11-02 00:00:00'], label = 'Reservations')
ax1.set_title("Visits vs Reservations during a month")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
# Can see that in any given time window, many more people visit instead of reserve.

# %%
# Looking at aggregated windows

m1 = cum_df_visit['reserve_visitors'].groupby(by=[cum_df_visit.index.month]).sum()
m1_res = cum_df_reserve['reserve_visitors'].groupby(by=[cum_df_reserve.index.month]).sum()
m2 = cum_df_visit['reserve_visitors'].groupby(by=[cum_df_visit.index.weekday]).sum()
m2_res = cum_df_reserve['reserve_visitors'].groupby(by=[cum_df_reserve.index.weekday]).sum()
m3 = cum_df_visit['reserve_visitors'].groupby(by=[cum_df_visit.index.hour]).sum()
m3_res = cum_df_reserve['reserve_visitors'].groupby(by=[cum_df_reserve.index.hour]).sum()

# %%
fig,ax1 = plt.subplots(figsize = (12,6))
ax1.plot(m1, label = 'Visit')
ax1.plot(m1_res, label = 'Reservations')
ax1.set_title("Visits vs Reservations monthly ")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
# Can be seen that this ties in well with the combination of cherry blossom period (march/april) and Christams (dec)

# %%
fig,ax1 = plt.subplots(figsize = (12,6))
ax1.plot(m2, label = 'Visit')
ax1.plot(m2_res, label = 'Reservations')
ax1.set_title("Visits vs Reservations Aggregated during a week")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
fig,ax1 = plt.subplots(figsize = (12,6))
ax1.plot(m3, label = 'Visit')
ax1.plot(m3_res, label = 'Reservations')
ax1.set_title("Visits vs Reservations Aggregated during a day")
plt.ylabel("Number of visits")
plt.xlabel("Period")
plt.legend()
plt.show()

# %%
# Now I'll explore how many visitors per genre

# %%
# First with air_genre
air_genre = df_air.groupby(by='air_genre_name').sum().drop(['latitude', 'longitude'],axis = 1).sort_values(by=['reserve_visitors'],ascending=True)

# %%
fig, ax = plt.subplots(figsize = (24,12))
sns.barplot(x = air_genre.index, y ='reserve_visitors', data = air_genre)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Then with with hpg_genre
hpg_genre = df_hpg.groupby(by='hpg_genre_name').sum().drop(['latitude', 'longitude'],axis = 1).sort_values(by=['reserve_visitors'],ascending=True)

# %%
hpg_genre
# Out:
#                               reserve_visitors
# hpg_genre_name
# Spain/Mediterranean cuisine                531
# Udon/Soba                                  623
# Sweets                                     795
# Shanghai food                             1177
# Taiwanese/Hong Kong cuisine               1445
# Dim Sum/Dumplings                         1609
# Amusement bar                             1966
# Sichuan food                              2809
# Cantonese food                            3581
# Thai/Vietnamese food                      4083
# Western food                              4639
# Bar/Cocktail                              5108
# Pasta/Pizza                               6259
# Sushi                                     8674
# Cafe                                     15635
# Bistro                                   15670
# Steak/Hamburger/Curry                    18629
# French                                   24929
# Party                                    32932
# Okonomiyaki/Monja/Teppanyaki             38917
# Korean cuisine                           39391
# Karaoke                                  47632
# Creative Japanese food                   52543
# Japanese cuisine/Kaiseki                 53615
# Shabu-shabu/Sukiyaki                     64351
# Chinese general                          76689
# Japanese food in general                 92482
# Spain Bar/Italian Bar                   224489
# Italian                                 252603
# Grilled meat                            304829
# Seafood                                 342091
# Creation                                393471
# International cuisine                   662911
# Japanese style                         1851637

# %%
fig, ax = plt.subplots(figsize = (28,12))
sns.barplot(x = hpg_genre.index, y ='reserve_visitors', data = hpg_genre)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
# Difference is large between two datasets!

# If you want to start a restaurant, you'd be better off making one that serves japanes food!

# %%
# Getting dates which are holidays, but NOT saturday or sunday!
dates = date_info.loc[date_info['holiday_flg']==1].loc[(date_info['day_of_week'] !='Saturday')].loc[date_info['day_of_week'] !='Sunday']
dates.head()
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 10     2016-01-11      Monday            1
# 41     2016-02-11    Thursday            1
# 80     2016-03-21      Monday            1
# 119    2016-04-29      Friday            1

# %%
# Making a new feature that states if visit occured on a holiday

# %%
#Extracting times and dates from visit and reserves

visit_datetime = pd.to_datetime(df_full['visit_datetime'])
reserve_datetime = pd.to_datetime(df_full['reserve_datetime'])

# Making a new column for visit/reserve dates and time from dt.date/time
df_full['visit_date']=visit_datetime.dt.date
df_full['visit_time']=visit_datetime.dt.time
df_full['reserve_date']=reserve_datetime.dt.date
df_full['reserve_time']=reserve_datetime.dt.time

# %%
df_full.head()
# Out:
#                              hpg_store_id      visit_datetime  \
# visit_datetime
# 2016-01-01 13:00:00  hpg_dac72789163a3f47 2016-01-01 13:00:00
# 2016-01-02 12:00:00  hpg_dac72789163a3f47 2016-01-02 12:00:00
# 2016-01-03 19:00:00  hpg_dac72789163a3f47 2016-01-03 19:00:00
# 2016-01-06 12:00:00  hpg_dac72789163a3f47 2016-01-06 12:00:00
# 2016-01-10 17:00:00  hpg_dac72789163a3f47 2016-01-10 17:00:00
#
#                        reserve_datetime  reserve_visitors hpg_genre_name  \
# visit_datetime
# 2016-01-01 13:00:00 2016-01-01 06:00:00                 3         French
# 2016-01-02 12:00:00 2016-01-01 20:00:00                 2         French
# 2016-01-03 19:00:00 2016-01-02 15:00:00                 2         French
# 2016-01-06 12:00:00 2016-01-06 08:00:00                 2         French
# 2016-01-10 17:00:00 2016-01-04 22:00:00                 3         French
#
#                                hpg_area_name   latitude   longitude  \
# visit_datetime
# 2016-01-01 13:00:00  Hyōgo-ken Kōbe-shi None  34.692109  135.191698
# 2016-01-02 12:00:00  Hyōgo-ken Kōbe-shi None  34.692109  135.191698
# 2016-01-03 19:00:00  Hyōgo-ken Kōbe-shi None  34.692109  135.191698
# 2016-01-06 12:00:00  Hyōgo-ken Kōbe-shi None  34.692109  135.191698
# 2016-01-10 17:00:00  Hyōgo-ken Kōbe-shi None  34.692109  135.191698
#
#                     air_store_id air_genre_name air_area_name  cluster  \
# visit_datetime
# 2016-01-01 13:00:00          NaN            NaN           NaN        4
# 2016-01-02 12:00:00          NaN            NaN           NaN        4
# 2016-01-03 19:00:00          NaN            NaN           NaN        4
# 2016-01-06 12:00:00          NaN            NaN           NaN        4
# 2016-01-10 17:00:00          NaN            NaN           NaN        4
#
#                      visit_date visit_time reserve_date reserve_time
# visit_datetime
# 2016-01-01 13:00:00  2016-01-01   13:00:00   2016-01-01     06:00:00
# 2016-01-02 12:00:00  2016-01-02   12:00:00   2016-01-01     20:00:00
# 2016-01-03 19:00:00  2016-01-03   19:00:00   2016-01-02     15:00:00
# 2016-01-06 12:00:00  2016-01-06   12:00:00   2016-01-06     08:00:00
# 2016-01-10 17:00:00  2016-01-10   17:00:00   2016-01-04     22:00:00

# %%
date_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   calendar_date  517 non-null    object
#  1   day_of_week    517 non-null    object
#  2   holiday_flg    517 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 12.2+ KB

# %%
# Making a series from calendar_date

dates = pd.to_datetime(date_info['calendar_date'])

# %%
days_of_the_week = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

# %%
date_info['calendar_date'] = pd.to_datetime(date_info['calendar_date']).dt.date

# %%
# Adding day of the week and day of the year to date_info

date_info['day_of_year'] = dates.dt.dayofyear
date_info['day_of_week'] = [days.index(dw) for dw in date_info['day_of_week']]

# %%
# Merging the holiday flags with full df!!!

new_df_full = pd.merge(df_full,date_info[['calendar_date','holiday_flg']],how='left',left_on='visit_date',right_on='calendar_date')

# %%
# Renaming column from holiday_flg to visit_holiday

new_df_full = new_df_full.rename(index = str, columns = {'holiday_flg':'visit_holiday'})

# %%
new_df_full = new_df_full.drop(['calendar_date'],axis=1)

# %%
new_df_full
# Out:
#                 hpg_store_id      visit_datetime    reserve_datetime  \
# 0       hpg_dac72789163a3f47 2016-01-01 13:00:00 2016-01-01 06:00:00
# 1       hpg_dac72789163a3f47 2016-01-02 12:00:00 2016-01-01 20:00:00
# 2       hpg_dac72789163a3f47 2016-01-03 19:00:00 2016-01-02 15:00:00
# 3       hpg_dac72789163a3f47 2016-01-06 12:00:00 2016-01-06 08:00:00
# 4       hpg_dac72789163a3f47 2016-01-10 17:00:00 2016-01-04 22:00:00
# ...                      ...                 ...                 ...
# 963681                   NaN 2017-05-16 19:00:00 2017-04-20 19:00:00
# 963682                   NaN 2017-05-21 18:00:00 2017-04-20 19:00:00
# 963683                   NaN 2017-05-21 19:00:00 2017-04-20 19:00:00
# 963684  hpg_e41e0f2c318dd8e4 2017-04-20 23:00:00 2017-04-20 10:00:00
# 963685                   NaN 2017-05-23 19:00:00 2017-04-14 16:00:00
#
#         reserve_visitors hpg_genre_name            hpg_area_name   latitude  \
# 0                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# 1                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 2                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 3                      2         French  Hyōgo-ken Kōbe-shi None  34.692109
# 4                      3         French  Hyōgo-ken Kōbe-shi None  34.692109
# ...                  ...            ...                      ...        ...
# 963681                 3            NaN                      NaN  35.658068
# 963682                 4            NaN                      NaN  35.658068
# 963683                 2            NaN                      NaN  35.658068
# 963684                 2            NaN                      NaN  34.705362
# 963685                11            NaN                      NaN  38.269076
#
#          longitude          air_store_id air_genre_name  \
# 0       135.191698                   NaN            NaN
# 1       135.191698                   NaN            NaN
# 2       135.191698                   NaN            NaN
# 3       135.191698                   NaN            NaN
# 4       135.191698                   NaN            NaN
# ...            ...                   ...            ...
# 963681  139.751599  air_b3a824511477a4ed  Japanese food
# 963682  139.751599  air_b3a824511477a4ed  Japanese food
# 963683  139.751599  air_b3a824511477a4ed  Japanese food
# 963684  135.510025  air_cf2229e64408d9fe     Dining bar
# 963685  140.870403  air_e700e390226d9985        Izakaya
#
#                          air_area_name  cluster  visit_date visit_time  \
# 0                                  NaN        4  2016-01-01   13:00:00
# 1                                  NaN        4  2016-01-02   12:00:00
# 2                                  NaN        4  2016-01-03   19:00:00
# 3                                  NaN        4  2016-01-06   12:00:00
# 4                                  NaN        4  2016-01-10   17:00:00
# ...                                ...      ...         ...        ...
# 963681    Tōkyō-to Minato-ku Shibakōen        3  2017-05-16   19:00:00
# 963682    Tōkyō-to Minato-ku Shibakōen        3  2017-05-21   18:00:00
# 963683    Tōkyō-to Minato-ku Shibakōen        3  2017-05-21   19:00:00
# 963684     Ōsaka-fu Ōsaka-shi Ōgimachi        4  2017-04-20   23:00:00
# 963685  Miyagi-ken Sendai-shi Kamisugi        7  2017-05-23   19:00:00
#
#        reserve_date reserve_time  visit_holiday
# 0        2016-01-01     06:00:00              1
# 1        2016-01-01     20:00:00              1
# 2        2016-01-02     15:00:00              1
# 3        2016-01-06     08:00:00              0
# 4        2016-01-04     22:00:00              0
# ...             ...          ...            ...
# 963681   2017-04-20     19:00:00              0
# 963682   2017-04-20     19:00:00              0
# 963683   2017-04-20     19:00:00              0
# 963684   2017-04-20     10:00:00              0
# 963685   2017-04-14     16:00:00              0
#
# [963686 rows x 17 columns]

# %%
# Doing the same, but for the reservation info

new_df_full = pd.merge(new_df_full,date_info[['calendar_date','holiday_flg']],how='left',left_on='reserve_date',right_on='calendar_date')
new_df_full = new_df_full.rename(index = str, columns = {'holiday_flg':'reservation_holiday'})
new_df_full = new_df_full.drop(['calendar_date'],axis=1)

# %%
# Getting days of the year for visit and reserve dates

new_df_full['visit_date'] = pd.to_datetime(new_df_full['visit_date']).dt.dayofyear
new_df_full['reserve_date'] = pd.to_datetime(new_df_full['reserve_date']).dt.dayofyear

# %%
# Can now estimate time between reservations and visits!

time_between_res_vis = visit_datetime-reserve_datetime
delta = time_between_res_vis.dt.days
delta.describe()
# Out:
# count    963686.000000
# mean          6.909061
# std          11.507296
# min           0.000000
# 25%           1.000000
# 50%           4.000000
# 75%           9.000000
# max         393.000000
# dtype: float64

# %%
# Making a distribution plot

fig, ax = plt.subplots(figsize = (18,6))
ax = sns.histplot(delta, bins = 380, kde = True)
plt.title('Distribution of times between booking and visiting')
plt.xlim(0,30)
plt.show()

# %%
# Making a distribution plot

fig, ax = plt.subplots(figsize = (18,6))
ax = sns.boxplot(x = delta)
plt.title('Distribution of times between booking and visiting')
plt.xlim(0,30)
plt.show()

# %%
# Checking vists and reservations during holidays 

holihist_visit = new_df_full[new_df_full['visit_holiday']==1].groupby(['visit_date'],as_index=False).count()
non_holihist_visit = new_df_full[new_df_full['visit_holiday']==0].groupby(['visit_date'],as_index=False).count()
holihist_reserve = new_df_full[new_df_full['visit_holiday']==1].groupby(['reserve_date'],as_index=False).count()
non_holihist_reserve = new_df_full[new_df_full['visit_holiday']==0].groupby(['reserve_date'],as_index=False).count()

# %%
# Plotting results!

# %%
fig,ax = plt.subplots(1,1,figsize=(20,12))
sns.barplot(x = holihist_visit['visit_date'], y=holihist_visit['visit_datetime'])
plt.title('Visits during holiday days')
plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(20,12))
sns.barplot(x = holihist_reserve['reserve_date'], y=holihist_reserve['reserve_datetime'])
plt.title('Bookings during holiday days')
plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(20,12))
sns.barplot(x = non_holihist_visit['visit_date'][0:120], y=non_holihist_visit['visit_datetime'])
plt.title('Visits during regular days')
plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(20,12))
sns.barplot(x = non_holihist_reserve['reserve_date'][0:60], y=non_holihist_reserve['reserve_datetime'])
plt.title('Bookings during regular days')
plt.tight_layout()
plt.show()

# %%
# Initialise RNN definitions - making a unified df for reserve and visits

reserve = cum_df_reserve.drop(['latitude','longitude'], axis = 1)
visit = cum_df_visit.drop(['latitude','longitude'], axis = 1)

# %%
visit.resample('1H', label='right').sum()
# Out:
#                      reserve_visitors
# visit_datetime
# 2016-01-01 14:00:00                 3
# 2016-01-01 15:00:00                 0
# 2016-01-01 16:00:00                 0
# 2016-01-01 17:00:00                 0
# 2016-01-01 18:00:00                35
# ...                               ...
# 2017-05-31 20:00:00                37
# 2017-05-31 21:00:00                13
# 2017-05-31 22:00:00                12
# 2017-05-31 23:00:00                 0
# 2017-06-01 00:00:00                 6
#
# [12395 rows x 1 columns]

# %%
visit[0:100].plot()
# Out:
# <AxesSubplot:xlabel='visit_datetime'>

# %%
visit.plot()
# Out:
# <AxesSubplot:xlabel='visit_datetime'>

# %%
reserve.plot()
# Out:
# <AxesSubplot:xlabel='reserve_datetime'>

# %%
# Merging both dfs
unified = pd.merge(reserve,visit,left_index=True, right_index=True,how="outer")

# %%
unified = unified.fillna(value=0)

# %%
unified.columns=['reservations','visitors']

# %%
unified[1:100].plot()
# Out:
# <AxesSubplot:>

# %%
# Now we have reserve, visits and unified for neural network usage

# %%
print(len(reserve), len(visit))
# Out:
# 11421 8678

# %%
# Starting with Visit df

# %%
#visit_resample = visit.resample('H').sum()

# %%
visit_resample = visit

# %%
visit_resample
# Out:
#                      reserve_visitors
# visit_datetime
# 2016-01-01 13:00:00                 3
# 2016-01-01 17:00:00                35
# 2016-01-01 18:00:00                84
# 2016-01-01 19:00:00               106
# 2016-01-01 20:00:00                26
# ...                               ...
# 2017-05-31 18:00:00               171
# 2017-05-31 19:00:00                37
# 2017-05-31 20:00:00                13
# 2017-05-31 21:00:00                12
# 2017-05-31 23:00:00                 6
#
# [8678 rows x 1 columns]

# %%
visit_resample.shape
# Out:
# (8678, 1)

# %%
train_size = int(len(visit_resample)*0.8)

# %%
train_size
# Out:
# 6942

# %%
# Train/test split
train = visit_resample .iloc[:train_size]
test = visit_resample .iloc[train_size:]

# %%
print(len(train), len(test))
# Out:
# 6942 1736

# %%
# Scaling

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
# Getting timeseries generator
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
scaled_train
# Out:
# array([[4.35929292e-05],
#        [7.41079797e-04],
#        [1.80910656e-03],
#        ...,
#        [2.19490399e-02],
#        [6.93127575e-03],
#        [1.85269949e-03]])

# %%
# Redefine to get 36! months back and then predict the next month out
n_input = 24
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [4.35929292e-05 7.41079797e-04 1.80910656e-03 2.28862878e-03
#  5.44911615e-04 2.17964646e-05 1.74371717e-04 1.08982323e-04
#  3.05150505e-04 5.44911615e-04 2.39761111e-04 3.70539898e-04
#  1.08982323e-04 6.14660302e-03 1.34484187e-02 9.78661261e-03
#  3.24767323e-03 1.35138081e-03 3.92336363e-04 2.17964646e-05
#  2.39761111e-04 1.08982323e-04 7.62876261e-04 6.75690403e-04]
# Predict this y:
#  [[0.00056671]]

# %%
#Creating model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=5)
n_features = 1

# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss="mean_squared_logarithmic_error")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-2890d57c1569> in <module>
# ----> 1 validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)
#
# NameError: name 'length' is not defined

# %%
# fit model
model.fit(generator,epochs=50,callbacks=[early_stop],validation_data=validation_generator)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-d606ba8a0ce7> in <module>
#       1 # fit model
# ----> 2 model.fit(generator,epochs=50,callbacks=[early_stop],validation_data=validation_generator)
#
# NameError: name 'validation_generator' is not defined

# %%
model.history.history.keys()
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-f95a8b82a2d0> in <module>
# ----> 1 model.history.history.keys()
#       2 loss_per_epoch = model.history.history['loss']
#       3 plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %%
# Evaluating on test data

first_eval_batch = scaled_train[-24:]
first_eval_batch
# Out:
# array([[0.00021796],
#        [0.0006103 ],
#        [0.00198348],
#        [0.01220602],
#        [0.07011923],
#        [0.07434774],
#        [0.02079383],
#        [0.00714924],
#        [0.00272456],
#        [0.0005885 ],
#        [0.00047952],
#        [0.00021796],
#        [0.00387977],
#        [0.0037054 ],
#        [0.00222324],
#        [0.00043593],
#        [0.00045773],
#        [0.00071928],
#        [0.00913272],
#        [0.06913839],
#        [0.07800955],
#        [0.02194904],
#        [0.00693128],
#        [0.0018527 ]])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.00052964], dtype=float32),
#  array([0.00033034], dtype=float32),
#  array([0.00019535], dtype=float32),
#  array([0.00010828], dtype=float32),
#  array([5.561152e-05], dtype=float32),
#  array([2.4495434e-05], dtype=float32),
#  array([7.3907704e-06], dtype=float32),
#  array([3.2863954e-07], dtype=float32),
#  array([-8.5895545e-07], dtype=float32),
#  array([1.0136528e-06], dtype=float32),
#  array([4.037478e-06], dtype=float32),
#  array([7.132541e-06], dtype=float32),
#  array([9.649691e-06], dtype=float32),
#  array([1.1237998e-05], dtype=float32),
#  array([1.1926564e-05], dtype=float32),
#  array([1.2041166e-05], dtype=float32),
#  array([1.1745364e-05], dtype=float32),
#  array([1.1213856e-05], dtype=float32),
#  array([1.0443956e-05], dtype=float32),
#  array([9.1693e-06], dtype=float32),
#  array([5.101289e-06], dtype=float32),
#  array([1.4262407e-06], dtype=float32),
#  array([3.710749e-07], dtype=float32),
#  array([1.827292e-07], dtype=float32),
#  array([1.15061624e-07], dtype=float32),
#  array([7.796834e-08], dtype=float32),
#  array([4.7752795e-08], dtype=float32),
#  array([2.6182938e-08], dtype=float32),
#  array([1.3388739e-08], dtype=float32),
#  array([6.905757e-09], dtype=float32),
#  array([4.3292276e-09], dtype=float32),
#  array([3.83373e-09], dtype=float32),
#  array([4.190087e-09], dtype=float32),
#  array([4.7792343e-09], dtype=float32),
#  array([5.2431677e-09], dtype=float32),
#  array([5.4429714e-09], dtype=float32),
#  array([5.2096443e-09], dtype=float32),
#  array([4.6694812e-09], dtype=float32),
#  array([3.9807464e-09], dtype=float32),
#  array([3.2857659e-09], dtype=float32),
#  array([2.610688e-09], dtype=float32),
#  array([1.9660857e-09], dtype=float32),
#  array([1.3453128e-09], dtype=float32),
#  array([8.286443e-10], dtype=float32),
#  array([3.3215453e-10], dtype=float32),
#  array([9.369069e-11], dtype=float32),
#  array([5.3627526e-11], dtype=float32),
#  array([3.636357e-11], dtype=float32),
#  array([2.5045509e-11], dtype=float32),
#  array([1.7030129e-11], dtype=float32),
#  array([1.1106975e-11], dtype=float32),
#  array([7.084203e-12], dtype=float32),
#  array([4.635129e-12], dtype=float32),
#  array([3.484597e-12], dtype=float32),
#  array([2.9752145e-12], dtype=float32),
#  array([2.726909e-12], dtype=float32),
#  array([2.545202e-12], dtype=float32),
#  array([2.3539473e-12], dtype=float32),
#  array([2.0829352e-12], dtype=float32),
#  array([1.7493754e-12], dtype=float32),
#  array([1.4014404e-12], dtype=float32),
#  array([1.0864807e-12], dtype=float32),
#  array([8.1635924e-13], dtype=float32),
#  array([5.8632195e-13], dtype=float32),
#  array([3.8920616e-13], dtype=float32),
#  array([2.4860428e-13], dtype=float32),
#  array([1.4010436e-13], dtype=float32),
#  array([6.6260115e-14], dtype=float32),
#  array([3.0732354e-14], dtype=float32),
#  array([1.6363941e-14], dtype=float32),
#  array([1.1512974e-14], dtype=float32),
#  array([8.167397e-15], dtype=float32),
#  array([5.7434136e-15], dtype=float32),
#  array([4.1274433e-15], dtype=float32),
#  array([2.892136e-15], dtype=float32),
#  array([2.0981588e-15], dtype=float32),
#  array([1.6242317e-15], dtype=float32),
#  array([1.3394815e-15], dtype=float32),
#  array([1.139521e-15], dtype=float32),
#  array([9.653322e-16], dtype=float32),
#  array([8.05423e-16], dtype=float32),
#  array([6.5313615e-16], dtype=float32),
#  array([5.0396057e-16], dtype=float32),
#  array([3.7819677e-16], dtype=float32),
#  array([2.744715e-16], dtype=float32),
#  array([1.9257393e-16], dtype=float32),
#  array([1.2979836e-16], dtype=float32),
#  array([8.3165235e-17], dtype=float32),
#  array([5.0548207e-17], dtype=float32),
#  array([2.8847547e-17], dtype=float32),
#  array([1.552852e-17], dtype=float32),
#  array([8.248513e-18], dtype=float32),
#  array([5.2658024e-18], dtype=float32),
#  array([3.5930253e-18], dtype=float32),
#  array([2.6266885e-18], dtype=float32),
#  array([1.9306108e-18], dtype=float32),
#  array([1.4124706e-18], dtype=float32),
#  array([1.0478851e-18], dtype=float32),
#  array([7.859308e-19], dtype=float32),
#  array([6.1443565e-19], dtype=float32),
#  array([4.918899e-19], dtype=float32),
#  array([3.9345862e-19], dtype=float32),
#  array([3.150436e-19], dtype=float32),
#  array([2.4622507e-19], dtype=float32),
#  array([1.8555914e-19], dtype=float32),
#  array([1.3701301e-19], dtype=float32),
#  array([9.7800556e-20], dtype=float32),
#  array([6.773645e-20], dtype=float32),
#  array([4.540333e-20], dtype=float32),
#  array([2.9601172e-20], dtype=float32),
#  array([1.875728e-20], dtype=float32),
#  array([1.1460445e-20], dtype=float32),
#  array([6.635153e-21], dtype=float32),
#  array([3.8219977e-21], dtype=float32),
#  array([2.404052e-21], dtype=float32),
#  array([1.6164713e-21], dtype=float32),
#  array([1.1446178e-21], dtype=float32),
#  array([8.395848e-22], dtype=float32),
#  array([6.2662804e-22], dtype=float32),
#  array([4.6843464e-22], dtype=float32),
#  array([3.5183373e-22], dtype=float32),
#  array([2.6857682e-22], dtype=float32),
#  array([2.0591121e-22], dtype=float32),
#  array([1.6023493e-22], dtype=float32),
#  array([1.2318403e-22], dtype=float32),
#  array([9.3877957e-23], dtype=float32),
#  array([6.968803e-23], dtype=float32),
#  array([5.0999747e-23], dtype=float32),
#  array([3.5833196e-23], dtype=float32),
#  array([2.4767194e-23], dtype=float32),
#  array([1.6657476e-23], dtype=float32),
#  array([1.0981735e-23], dtype=float32),
#  array([7.03278e-24], dtype=float32),
#  array([4.413874e-24], dtype=float32),
#  array([2.707848e-24], dtype=float32),
#  array([1.6518371e-24], dtype=float32),
#  array([1.0530785e-24], dtype=float32),
#  array([7.098591e-25], dtype=float32),
#  array([4.986144e-25], dtype=float32),
#  array([3.6034367e-25], dtype=float32),
#  array([2.658421e-25], dtype=float32),
#  array([1.997003e-25], dtype=float32),
#  array([1.4934156e-25], dtype=float32),
#  array([1.1275242e-25], dtype=float32),
#  array([8.5097076e-26], dtype=float32),
#  array([6.4291276e-26], dtype=float32),
#  array([4.831619e-26], dtype=float32),
#  array([3.61871e-26], dtype=float32),
#  array([2.654545e-26], dtype=float32),
#  array([1.9109682e-26], dtype=float32),
#  array([1.3434475e-26], dtype=float32),
#  array([9.254141e-27], dtype=float32),
#  array([6.2514654e-27], dtype=float32),
#  array([4.14029e-27], dtype=float32),
#  array([2.6857794e-27], dtype=float32),
#  array([1.7147361e-27], dtype=float32),
#  array([1.08046095e-27], dtype=float32),
#  array([6.8681474e-28], dtype=float32),
#  array([4.474053e-28], dtype=float32),
#  array([3.0338893e-28], dtype=float32),
#  array([2.125274e-28], dtype=float32),
#  array([1.530404e-28], dtype=float32),
#  array([1.1207861e-28], dtype=float32),
#  array([8.251238e-29], dtype=float32),
#  array([6.183634e-29], dtype=float32),
#  array([4.6191522e-29], dtype=float32),
#  array([3.446724e-29], dtype=float32),
#  array([2.570534e-29], dtype=float32),
#  array([1.9020844e-29], dtype=float32),
#  array([1.4006977e-29], dtype=float32),
#  array([1.017067e-29], dtype=float32),
#  array([7.257845e-30], dtype=float32),
#  array([5.0777463e-30], dtype=float32),
#  array([3.4966413e-30], dtype=float32),
#  array([2.3668498e-30], dtype=float32),
#  array([1.5773235e-30], dtype=float32),
#  array([1.0347554e-30], dtype=float32),
#  array([6.692012e-31], dtype=float32),
#  array([4.3121995e-31], dtype=float32),
#  array([2.8083646e-31], dtype=float32),
#  array([1.8582452e-31], dtype=float32),
#  array([1.2745258e-31], dtype=float32),
#  array([8.9462197e-32], dtype=float32),
#  array([6.399438e-32], dtype=float32),
#  array([4.631412e-32], dtype=float32),
#  array([3.4104923e-32], dtype=float32),
#  array([2.5221613e-32], dtype=float32),
#  array([1.8625285e-32], dtype=float32),
#  array([1.3845958e-32], dtype=float32),
#  array([1.02085476e-32], dtype=float32),
#  array([7.48187e-33], dtype=float32),
#  array([5.4378843e-33], dtype=float32),
#  array([3.911057e-33], dtype=float32),
#  array([2.7781435e-33], dtype=float32),
#  array([1.9375043e-33], dtype=float32),
#  array([1.3296992e-33], dtype=float32),
#  array([9.009234e-34], dtype=float32),
#  array([6.0474937e-34], dtype=float32),
#  array([3.9993183e-34], dtype=float32),
#  array([2.6217813e-34], dtype=float32),
#  array([1.7190994e-34], dtype=float32),
#  array([1.1383237e-34], dtype=float32),
#  array([7.6575754e-35], dtype=float32),
#  array([5.270975e-35], dtype=float32),
#  array([3.7035522e-35], dtype=float32),
#  array([2.641291e-35], dtype=float32),
#  array([1.9085596e-35], dtype=float32),
#  array([1.3959106e-35], dtype=float32),
#  array([1.0204564e-35], dtype=float32),
#  array([7.480292e-36], dtype=float32),
#  array([5.5231177e-36], dtype=float32),
#  array([4.0374694e-36], dtype=float32),
#  array([2.9383917e-36], dtype=float32),
#  array([2.1148079e-36], dtype=float32),
#  array([1.4744242e-36], dtype=float32),
#  array([1.0416682e-36], dtype=float32),
#  array([7.363747e-37], dtype=float32),
#  array([5.1282484e-37], dtype=float32),
#  array([3.4944388e-37], dtype=float32),
#  array([2.4606245e-37], dtype=float32),
#  array([1.0273088e-37], dtype=float32),
#  array([6.586841e-38], dtype=float32),
#  array([2.9733973e-38], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.7898872e-38], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  ...]

# %%
scaled_test

# %%
# Perform inverse tranformations for better comparison

true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[25.29942322],
#        [16.15550065],
#        [ 9.96235598],
#        ...,
#        [ 1.        ],
#        [ 1.        ],
#        [ 1.        ]])

# %%
test['Predictions'] = true_predictions
# Out:
# /Users/kieranodonnell/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test[200:700].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='visit_datetime'>

# %%
series = visit_resample['reserve_visitors'].values.reshape(-1,1)

# %%
series
# Out:
# array([[ 3],
#        [35],
#        [84],
#        ...,
#        [13],
#        [12],
#        [ 6]])

# %%
# Building dataset

T = 24 # T past timesteps used for predictions
X = []
Y = []

for t in range(len(series)-T):
    x = series[t:t+T]
    y = series[t+T]
    X.append(x)
    Y.append(y)
    
X = np.array(X).reshape(-1,T)
Y = np.array(Y)
N = len(X)
print(f"X shape is {X.shape} and Y shape is {Y.shape}")
# Out:
# X shape is (8654, 24) and Y shape is (8654, 1)

# %%
from tensorflow.keras.layers import Input, Dense, SimpleRNN
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
# Making autoregressive model

i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i,x)

model.compile(loss='mse', optimizer=Adam(lr=0.01))

# Train model -> splitting at 0.3 and validates at 0.3

r = model.fit(X[:-N//3], Y[:-N//3],
             epochs = 100,
             validation_data = (X[-N//3:], Y[-N//3:]))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 0s 2ms/step - loss: 776519.3750 - val_loss: 3441528.7500
# Epoch 2/100
# 181/181 [==============================] - 0s 1ms/step - loss: 472852.9375 - val_loss: 3444541.7500
# Epoch 3/100
# 181/181 [==============================] - 0s 1ms/step - loss: 455171.3438 - val_loss: 3142216.0000
# Epoch 4/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435543.5000 - val_loss: 3276483.7500
# Epoch 5/100
# 181/181 [==============================] - 0s 1ms/step - loss: 438184.2188 - val_loss: 3243226.2500
# Epoch 6/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435106.7188 - val_loss: 3323326.2500
# Epoch 7/100
# 181/181 [==============================] - 0s 1ms/step - loss: 441304.7188 - val_loss: 3146731.0000
# Epoch 8/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433908.0625 - val_loss: 3208651.0000
# Epoch 9/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434460.5000 - val_loss: 3143643.5000
# Epoch 10/100
# 181/181 [==============================] - 0s 1ms/step - loss: 436489.5938 - val_loss: 3218352.7500
# Epoch 11/100
# 181/181 [==============================] - 0s 1ms/step - loss: 437281.5938 - val_loss: 3160379.5000
# Epoch 12/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432429.0312 - val_loss: 3283042.7500
# Epoch 13/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433290.0000 - val_loss: 3182593.5000
# Epoch 14/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434141.0625 - val_loss: 3354865.2500
# Epoch 15/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431923.1562 - val_loss: 3149430.0000
# Epoch 16/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433091.2812 - val_loss: 3159543.2500
# Epoch 17/100
# 181/181 [==============================] - 0s 1ms/step - loss: 439462.4375 - val_loss: 3187811.7500
# Epoch 18/100
# 181/181 [==============================] - 0s 1ms/step - loss: 438757.7188 - val_loss: 3283899.2500
# Epoch 19/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433132.8750 - val_loss: 3319455.2500
# Epoch 20/100
# 181/181 [==============================] - 0s 1ms/step - loss: 443963.9062 - val_loss: 3198155.5000
# Epoch 21/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432865.2500 - val_loss: 3151838.2500
# Epoch 22/100
# 181/181 [==============================] - 0s 1ms/step - loss: 439196.3750 - val_loss: 3291915.0000
# Epoch 23/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434617.2188 - val_loss: 3141442.5000
# Epoch 24/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433646.4688 - val_loss: 3162452.5000
# Epoch 25/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430394.3438 - val_loss: 3319139.7500
# Epoch 26/100
# 181/181 [==============================] - 0s 1ms/step - loss: 437017.8125 - val_loss: 3209948.5000
# Epoch 27/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431944.1875 - val_loss: 3401404.0000
# Epoch 28/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435007.5000 - val_loss: 3155646.7500
# Epoch 29/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432778.6875 - val_loss: 3124685.5000
# Epoch 30/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432318.7188 - val_loss: 3331072.0000
# Epoch 31/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433556.5312 - val_loss: 3294000.0000
# Epoch 32/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435274.3750 - val_loss: 3093416.0000
# Epoch 33/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430870.7500 - val_loss: 3175052.5000
# Epoch 34/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434038.5625 - val_loss: 3366434.5000
# Epoch 35/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435542.2188 - val_loss: 3381961.5000
# Epoch 36/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435463.5938 - val_loss: 3199017.5000
# Epoch 37/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431335.5000 - val_loss: 3426360.5000
# Epoch 38/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434444.4375 - val_loss: 3215429.5000
# Epoch 39/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433597.7188 - val_loss: 3137347.5000
# Epoch 40/100
# 181/181 [==============================] - 0s 1ms/step - loss: 439317.0312 - val_loss: 3301546.7500
# Epoch 41/100
# 181/181 [==============================] - 0s 1ms/step - loss: 437301.3438 - val_loss: 3159435.7500
# Epoch 42/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432994.7812 - val_loss: 3164674.0000
# Epoch 43/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432654.6875 - val_loss: 3159636.0000
# Epoch 44/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432730.0000 - val_loss: 3292142.2500
# Epoch 45/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435910.6250 - val_loss: 3335539.0000
# Epoch 46/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435778.0000 - val_loss: 3237758.5000
# Epoch 47/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431642.8438 - val_loss: 3221014.2500
# Epoch 48/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430432.6562 - val_loss: 3162752.2500
# Epoch 49/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435059.8125 - val_loss: 3142872.2500
# Epoch 50/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431520.0938 - val_loss: 3152668.2500
# Epoch 51/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431891.8750 - val_loss: 3191101.0000
# Epoch 52/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433163.2812 - val_loss: 3135968.5000
# Epoch 53/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434925.3750 - val_loss: 3274327.2500
# Epoch 54/100
# 181/181 [==============================] - 0s 1ms/step - loss: 436325.1250 - val_loss: 3309940.2500
# Epoch 55/100
# 181/181 [==============================] - 0s 1ms/step - loss: 428645.8750 - val_loss: 3224851.7500
# Epoch 56/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430805.9688 - val_loss: 3218470.2500
# Epoch 57/100
# 181/181 [==============================] - 0s 1ms/step - loss: 436176.0000 - val_loss: 3264306.2500
# Epoch 58/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433502.1562 - val_loss: 3257686.5000
# Epoch 59/100
# 181/181 [==============================] - 0s 1ms/step - loss: 440832.0938 - val_loss: 3117297.0000
# Epoch 60/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430817.1562 - val_loss: 3229680.7500
# Epoch 61/100
# 181/181 [==============================] - 0s 1ms/step - loss: 427836.4375 - val_loss: 3254201.2500
# Epoch 62/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430383.8750 - val_loss: 3287499.7500
# Epoch 63/100
# 181/181 [==============================] - 0s 1ms/step - loss: 438122.9062 - val_loss: 3220877.2500
# Epoch 64/100
# 181/181 [==============================] - 0s 1ms/step - loss: 429776.6875 - val_loss: 3158145.5000
# Epoch 65/100
# 181/181 [==============================] - 0s 1ms/step - loss: 428712.4062 - val_loss: 3245065.2500
# Epoch 66/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433447.8125 - val_loss: 3197987.5000
# Epoch 67/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431276.6250 - val_loss: 3132065.0000
# Epoch 68/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434921.5312 - val_loss: 3230518.5000
# Epoch 69/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432593.5000 - val_loss: 3284576.2500
# Epoch 70/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432867.1250 - val_loss: 3249715.2500
# Epoch 71/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434477.0938 - val_loss: 3173850.5000
# Epoch 72/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430847.5000 - val_loss: 3196750.5000
# Epoch 73/100
# 181/181 [==============================] - 0s 1ms/step - loss: 428834.7500 - val_loss: 3191026.0000
# Epoch 74/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433175.0625 - val_loss: 3165504.5000
# Epoch 75/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435895.6250 - val_loss: 3207603.7500
# Epoch 76/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431110.9688 - val_loss: 3179965.5000
# Epoch 77/100
# 181/181 [==============================] - 0s 1ms/step - loss: 429768.5625 - val_loss: 3280087.5000
# Epoch 78/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430798.4375 - val_loss: 3300325.7500
# Epoch 79/100
# 181/181 [==============================] - 0s 1ms/step - loss: 436286.7812 - val_loss: 3206354.5000
# Epoch 80/100
# 181/181 [==============================] - 0s 1ms/step - loss: 429838.8750 - val_loss: 3172423.7500
# Epoch 81/100
# 181/181 [==============================] - 0s 1ms/step - loss: 435113.1875 - val_loss: 3226457.5000
# Epoch 82/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430990.9688 - val_loss: 3076000.5000
# Epoch 83/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431152.7812 - val_loss: 3312068.2500
# Epoch 84/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430600.2188 - val_loss: 3158771.7500
# Epoch 85/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431611.4688 - val_loss: 3205241.5000
# Epoch 86/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431247.9375 - val_loss: 3247006.7500
# Epoch 87/100
# 181/181 [==============================] - 0s 1ms/step - loss: 427584.5625 - val_loss: 3228126.0000
# Epoch 88/100
# 181/181 [==============================] - 0s 1ms/step - loss: 429503.0000 - val_loss: 3215981.7500
# Epoch 89/100
# 181/181 [==============================] - 0s 1ms/step - loss: 440978.8438 - val_loss: 3253554.2500
# Epoch 90/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432548.0000 - val_loss: 3161005.2500
# Epoch 91/100
# 181/181 [==============================] - 0s 1ms/step - loss: 429828.5625 - val_loss: 3176338.2500
# Epoch 92/100
# 181/181 [==============================] - 0s 1ms/step - loss: 434569.4688 - val_loss: 3232588.5000
# Epoch 93/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432579.6875 - val_loss: 3150311.2500
# Epoch 94/100
# 181/181 [==============================] - 0s 1ms/step - loss: 430514.3750 - val_loss: 3294888.5000
# Epoch 95/100
# 181/181 [==============================] - 0s 1ms/step - loss: 431222.2188 - val_loss: 3170074.2500
# Epoch 96/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433197.6250 - val_loss: 3225251.5000
# Epoch 97/100
# 181/181 [==============================] - 0s 1ms/step - loss: 433653.6250 - val_loss: 3315879.5000
# Epoch 98/100
# 181/181 [==============================] - 0s 1ms/step - loss: 437414.8438 - val_loss: 3205123.2500
# Epoch 99/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432532.8750 - val_loss: 3245521.2500
# Epoch 100/100
# 181/181 [==============================] - 0s 1ms/step - loss: 432569.0000 - val_loss: 3179974.0000

# %%
plt.plot(r.history['loss'], label = 'loss')
plt.plot(r.history['val_loss'], label = 'val_loss')
plt.legend()

# %%
# Right way to predict: Forecast using self-predicted targets

val_target = Y[-N//3:]
val_pred = []

# Index for 1st validation point

prev_x = X[-N//3] # this is a 1D array of length T

while len(val_pred) < len(val_target):
    pred = model.predict(prev_x.reshape(1,-1))[0,0] # Need a scalar = 1x1 array
    
    # Update preds
    val_pred.append(pred)
    
    # Update inputs
    prev_x = np.roll(prev_x,-1)
    prev_x[-1] = pred

# %%
# Correct method -> plot not as good!
plt.figure(figsize=(24,12))
plt.plot(val_target, label = 'forecast - true')
plt.plot(val_pred, label = 'CORRECT! forecast - predicted')
plt.legend()

# %%
# Now using Simple RNNs

# Making Model

i = Input(shape=(T,1))
x = SimpleRNN(5, activation = 'tanh')(i)
x = Dense(1)(x)
model = Model(i,x)

model.compile(loss='mae', optimizer=Adam(lr=0.01))

# Train model -> splitting at 0.3 and validates at 0.3

r = model.fit(X[:-N//3], Y[:-N//3],
             epochs = 100,
             validation_data = (X[-N//3:], Y[-N//3:]))
# Out:
# Epoch 1/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1018333.3125 - val_loss: 7043428.5000
# Epoch 2/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007477.1875 - val_loss: 7089820.5000
# Epoch 3/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007770.9375 - val_loss: 7104069.5000
# Epoch 4/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007562.5000 - val_loss: 7126413.0000
# Epoch 5/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1005770.8125 - val_loss: 7050617.5000
# Epoch 6/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006988.3750 - val_loss: 7000894.0000
# Epoch 7/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006552.6875 - val_loss: 7198697.5000
# Epoch 8/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006944.6250 - val_loss: 7163924.0000
# Epoch 9/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1008192.0000 - val_loss: 7183124.5000
# Epoch 10/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006289.5625 - val_loss: 7055358.5000
# Epoch 11/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007885.3750 - val_loss: 7062390.0000
# Epoch 12/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006208.5000 - val_loss: 7140447.0000
# Epoch 13/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006427.1875 - val_loss: 7091199.5000
# Epoch 14/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007102.5000 - val_loss: 7157862.0000
# Epoch 15/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006255.8125 - val_loss: 7018808.5000
# Epoch 16/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007640.7500 - val_loss: 7096485.5000
# Epoch 17/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007146.1875 - val_loss: 7144219.0000
# Epoch 18/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006731.4375 - val_loss: 7071522.5000
# Epoch 19/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006326.7500 - val_loss: 7133268.5000
# Epoch 20/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007385.0000 - val_loss: 7059439.0000
# Epoch 21/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006830.9375 - val_loss: 7159380.5000
# Epoch 22/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1008185.6250 - val_loss: 7083260.5000
# Epoch 23/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006496.1250 - val_loss: 7067511.0000
# Epoch 24/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006888.0625 - val_loss: 7036463.5000
# Epoch 25/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007897.9375 - val_loss: 7059913.0000
# Epoch 26/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007253.2500 - val_loss: 7122973.0000
# Epoch 27/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007915.4375 - val_loss: 7056769.0000
# Epoch 28/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007417.6250 - val_loss: 7025532.5000
# Epoch 29/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007933.8750 - val_loss: 7124243.0000
# Epoch 30/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007153.0000 - val_loss: 7033427.5000
# Epoch 31/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007528.7500 - val_loss: 7104136.5000
# Epoch 32/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007436.3750 - val_loss: 7134102.0000
# Epoch 33/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1006316.0000 - val_loss: 7108018.0000
# Epoch 34/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007533.4375 - val_loss: 7067876.5000
# Epoch 35/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007404.6875 - val_loss: 7179694.0000
# Epoch 36/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1005839.3750 - val_loss: 7140314.0000
# Epoch 37/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1008434.8125 - val_loss: 7122394.0000
# Epoch 38/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007448.8750 - val_loss: 7078979.0000
# Epoch 39/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1005567.7500 - val_loss: 7145076.0000
# Epoch 40/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1008049.0000 - val_loss: 7089753.0000
# Epoch 41/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006937.4375 - val_loss: 7092298.0000
# Epoch 42/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007829.1875 - val_loss: 7137518.5000
# Epoch 43/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007597.6875 - val_loss: 7104475.0000
# Epoch 44/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1008189.0625 - val_loss: 7115017.5000
# Epoch 45/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007443.7500 - val_loss: 7084396.0000
# Epoch 46/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006861.0625 - val_loss: 7130669.0000
# Epoch 47/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007107.8750 - val_loss: 7126534.5000
# Epoch 48/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006629.0000 - val_loss: 7243249.5000
# Epoch 49/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007843.4375 - val_loss: 7117182.0000
# Epoch 50/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006560.3125 - val_loss: 7115552.0000
# Epoch 51/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006697.2500 - val_loss: 7044397.5000
# Epoch 52/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006206.8125 - val_loss: 7086050.0000
# Epoch 53/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006351.0625 - val_loss: 7017074.0000
# Epoch 54/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007470.3750 - val_loss: 7172422.5000
# Epoch 55/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007507.1250 - val_loss: 7162735.5000
# Epoch 56/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007442.7500 - val_loss: 7048619.0000
# Epoch 57/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007678.1875 - val_loss: 7107737.0000
# Epoch 58/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1008140.4375 - val_loss: 7110604.0000
# Epoch 59/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1007534.8125 - val_loss: 7022151.0000
# Epoch 60/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007451.8125 - val_loss: 7034433.0000
# Epoch 61/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007485.4375 - val_loss: 7106766.0000
# Epoch 62/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007233.5000 - val_loss: 7045480.5000
# Epoch 63/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007439.5000 - val_loss: 7081296.0000
# Epoch 64/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006861.8125 - val_loss: 7088973.5000
# Epoch 65/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006937.0000 - val_loss: 7137272.0000
# Epoch 66/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007310.2500 - val_loss: 7163962.0000
# Epoch 67/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007572.4375 - val_loss: 7089474.5000
# Epoch 68/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006105.3125 - val_loss: 7055423.0000
# Epoch 69/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007033.3750 - val_loss: 7106715.0000
# Epoch 70/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007407.6875 - val_loss: 7099014.0000
# Epoch 71/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007259.3750 - val_loss: 7102066.0000
# Epoch 72/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007340.3125 - val_loss: 7103777.5000
# Epoch 73/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006949.6875 - val_loss: 7103893.0000
# Epoch 74/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007078.0000 - val_loss: 7142256.0000
# Epoch 75/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006286.8125 - val_loss: 7153684.0000
# Epoch 76/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006471.6250 - val_loss: 7140259.5000
# Epoch 77/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1008037.3750 - val_loss: 7052685.0000
# Epoch 78/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007324.2500 - val_loss: 6989428.0000
# Epoch 79/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006896.0000 - val_loss: 7088415.0000
# Epoch 80/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007860.6250 - val_loss: 7141499.0000
# Epoch 81/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006853.3750 - val_loss: 7097170.5000
# Epoch 82/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007549.2500 - val_loss: 7136526.0000
# Epoch 83/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007371.3750 - val_loss: 7109585.5000
# Epoch 84/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007222.0625 - val_loss: 7120545.5000
# Epoch 85/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006963.0625 - val_loss: 7088894.0000
# Epoch 86/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007481.6250 - val_loss: 7192963.0000
# Epoch 87/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1008339.1250 - val_loss: 7195946.5000
# Epoch 88/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006558.1250 - val_loss: 7134872.0000
# Epoch 89/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007073.1250 - val_loss: 7083303.5000
# Epoch 90/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006055.1250 - val_loss: 7103986.0000
# Epoch 91/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007268.6250 - val_loss: 7119066.0000
# Epoch 92/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1005897.0625 - val_loss: 7018380.5000
# Epoch 93/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1005931.9375 - val_loss: 7148283.0000
# Epoch 94/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1006892.4375 - val_loss: 7084485.0000
# Epoch 95/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007002.3125 - val_loss: 7156689.0000
# Epoch 96/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007088.1875 - val_loss: 7098572.5000
# Epoch 97/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007427.5625 - val_loss: 7120361.0000
# Epoch 98/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007853.5625 - val_loss: 7224794.0000
# Epoch 99/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007338.1250 - val_loss: 7070812.0000
# Epoch 100/100
# 181/181 [==============================] - 1s 6ms/step - loss: 1007357.5625 - val_loss: 7089731.0000

# %%
plt.plot(r.history['loss'], label = 'loss')
plt.plot(r.history['val_loss'], label = 'val_loss')
plt.legend()

# %%
# Right way to predict: Forecast using self-predicted targets

val_target = Y[-N//3:]
val_pred = []

# Index for 1st validation point

prev_x = X[-N//3] # this is a 1D array of length T

while len(val_pred) < len(val_target):
    pred = model.predict(prev_x.reshape(1,-1,1))[0,0] # Need a scalar = 1x1 array
    
    # Update preds
    val_pred.append(pred)
    
    # Update inputs
    prev_x = np.roll(prev_x,-1)
    prev_x[-1] = pred

# %%
# Correct method -> plot not as good!
plt.figure(figsize=(24,12))
plt.plot(val_target, label = 'forecast - true')
plt.plot(val_pred, label = 'CORRECT! forecast - predicted')
plt.legend()

# %%
# Now adding more LST and GRUs
