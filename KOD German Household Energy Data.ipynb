# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import feather

# %%
df = pd.read_csv('household_data_60min_singleindex.csv',parse_dates=True, index_col=0)

# %%
df.drop('cet_cest_timestamp', inplace = True, axis = 1)

# %%
df.head()
# Out:
#                            DE_KN_industrial1_grid_import  \
# utc_timestamp
# 2014-12-11 17:00:00+00:00                            NaN
# 2014-12-11 18:00:00+00:00                            NaN
# 2014-12-11 19:00:00+00:00                            NaN
# 2014-12-11 20:00:00+00:00                            NaN
# 2014-12-11 21:00:00+00:00                            NaN
#
#                            DE_KN_industrial1_pv_1  DE_KN_industrial1_pv_2  \
# utc_timestamp
# 2014-12-11 17:00:00+00:00                     NaN                     NaN
# 2014-12-11 18:00:00+00:00                     NaN                     NaN
# 2014-12-11 19:00:00+00:00                     NaN                     NaN
# 2014-12-11 20:00:00+00:00                     NaN                     NaN
# 2014-12-11 21:00:00+00:00                     NaN                     NaN
#
#                            DE_KN_industrial2_grid_import  \
# utc_timestamp
# 2014-12-11 17:00:00+00:00                            NaN
# ...

# %%
#df_indi_2 = df['utc_timestamp','DE_KN_industrial2_grid_import','DE_KN_industrial2_storage_charge','DE_KN_industrial2_pv']

# %%
df_indi_2 = df.filter(['utc_timestamp','DE_KN_industrial2_grid_import','DE_KN_industrial2_storage_charge','DE_KN_industrial2_storage_decharge','DE_KN_industrial2_pv'], axis=1)

# %%
df_indi_2.head()
# Out:
#           utc_timestamp  DE_KN_industrial2_grid_import  \
# 0  2014-12-11T17:00:00Z                            NaN
# 1  2014-12-11T18:00:00Z                            NaN
# 2  2014-12-11T19:00:00Z                            NaN
# 3  2014-12-11T20:00:00Z                            NaN
# 4  2014-12-11T21:00:00Z                            NaN
#
#    DE_KN_industrial2_storage_charge  DE_KN_industrial2_storage_decharge  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    DE_KN_industrial2_pv
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df_indi_2.plot()
