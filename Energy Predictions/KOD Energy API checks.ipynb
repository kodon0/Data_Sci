# %%
from energy_trading_api import jepx 
df1 = jepx.spotLatest()
df1 = jepx.spotLatest("20190101")

# %%
df1['price'].plot()

# %%
df2 = jepx.spotLatest()
df2 = jepx.spotLatest("20190102")

# %%
df2['price'].plot()

# %%
df2 = jepx.spotLatest()

# %%
df2
# Out:
#           date  interval  price   volume
# 0   2020/07/07         1   3.69  32959.3
# 1   2020/07/07         2   3.64  34642.3
# 2   2020/07/07         3   3.60  35533.2
# 3   2020/07/07         4   3.60  36051.0
# 4   2020/07/07         5   3.59  36397.3
# 5   2020/07/07         6   3.59  36573.3
# 6   2020/07/07         7   3.61  36964.4
# 7   2020/07/07         8   3.63  37061.0
# 8   2020/07/07         9   3.61  36928.7
# 9   2020/07/07        10   3.61  36988.1
# 10  2020/07/07        11   3.59  37028.7
# 11  2020/07/07        12   3.59  37016.7
# 12  2020/07/07        13   3.59  37143.3
# 13  2020/07/07        14   3.63  37215.5
# 14  2020/07/07        15   4.26  37271.4
# 15  2020/07/07        16   4.37  37699.8
# 16  2020/07/07        17   5.18  38215.6
# 17  2020/07/07        18   5.41  38528.8
# 18  2020/07/07        19   6.41  39134.1
# 19  2020/07/07        20   6.67  39497.6
# 20  2020/07/07        21   6.54  41715.8
# 21  2020/07/07        22   6.88  41776.6
# ...

# %%
#this give half hourly data - if nothing specified it give steh latest day -> can make for loop

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      48 non-null     object
#  1   interval  48 non-null     int64
#  2   price     48 non-null     float64
#  3   volume    48 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
df = pd.read_excel('ice_electric-2020.xlsx')

# %%
df.index = df['Trade date']

# %%
df['Wtd avg price $/MWh'].plot(figsize = (18,9))

# %%
df
# Out:
#                           Price hub Trade date Delivery start date  \
# Trade date
# 2020-01-17      Indiana Hub RT Peak 2020-01-17          2020-01-20
# 2020-02-18      Indiana Hub RT Peak 2020-02-18          2020-02-19
# 2020-03-19      Indiana Hub RT Peak 2020-03-19          2020-03-20
# 2020-04-15      Indiana Hub RT Peak 2020-04-15          2020-04-16
# 2020-04-21      Indiana Hub RT Peak 2020-04-21          2020-04-22
# ...                             ...        ...                 ...
# 2020-06-22  SP15 EZ Gen DA LMP Peak 2020-06-22          2020-06-23
# 2020-06-23  SP15 EZ Gen DA LMP Peak 2020-06-23          2020-06-24
# 2020-06-24  SP15 EZ Gen DA LMP Peak 2020-06-24          2020-06-25
# 2020-06-25  SP15 EZ Gen DA LMP Peak 2020-06-25          2020-06-26
# 2020-06-30  SP15 EZ Gen DA LMP Peak 2020-06-30          2020-07-01
#
#            Delivery \nend date  High price $/MWh  Low price $/MWh  \
# Trade date
# 2020-01-17          2020-01-20             33.00            32.00
# ...
